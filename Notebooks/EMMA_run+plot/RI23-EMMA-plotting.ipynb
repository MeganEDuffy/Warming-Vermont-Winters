# %%
library(fs)
library(ggplot2)

home_dir <- Sys.getenv("HOME")
repo_dir <- file.path(home_dir, "OneDrive/git-repos/LCBP-interannual-EMMAs")
source(file.path(repo_dir, "Functions/plot_multi_event_emma_grid.R")) 
data_dir <- file.path(repo_dir, "Output/EMMA-results/")

wade_sampling_windows <- data.frame(
  start = as.POSIXct(c("2023-02-08 00:00", "2023-03-20 00:00", "2023-03-30 00:00"), tz = "UTC"),
  end   = as.POSIXct(c("2023-02-20 23:59", "2023-03-28 23:59", "2023-04-13 23:59"), tz = "UTC")
)

#larger timeframe
wade_sampling_windows <- data.frame(
  start = as.POSIXct(c("2023-02-08 00:00", "2023-03-20 00:00", "2023-03-30 00:00"), tz = "UTC"),
  end   = as.POSIXct(c("2023-02-20 23:59", "2023-03-28 23:59", "2023-04-13 23:59"), tz = "UTC")
)

# Shade these in pale yellow across panels
wade_shading_windows <- data.frame(
  start = as.POSIXct(c("2023-02-09 05:15", "2023-03-21 06:00", "2023-03-31 06:00"), tz = "UTC"),
  end   = as.POSIXct(c("2023-02-19 04:00", "2023-03-27 03:45", "2023-04-12 06:00"), tz = "UTC")
)

wade_emma_feb_ros = file.path(data_dir, "Wade_Feb_ROS_fractions.csv")
wade_emma_mar_thm = file.path(data_dir, "Wade_Mar_therm_fractions.csv")
wade_emma_freshet = file.path(data_dir, "Wade_spring_melt_fractions.csv")

emma_files_list <- c(
  wade_emma_feb_ros,
  wade_emma_mar_thm,
  wade_emma_freshet
)

event_titles_list <- c("February ROS", "March thermal", "Final spring melt")

wade_3x4_grid <- plot_multi_event_grid(
  site_name        = "Wade",
  q_file           = file.path(repo_dir, "Data/StreamSensor_data/wb_q_chem_20211001-20230930.csv"),
  snow_file        = file.path(repo_dir, "Data/Met_data/Wade_cocorahs-vt-fr-30-20221115-20250414-2.csv"),
  soil_file_6cm    = file.path(repo_dir, "Data/SoilSensor_data/Ranch_Brook/RanchBrook_TMS4_WY23_SML1_data.csv"),
  soil_file_15cm   = file.path(repo_dir, "Data/SoilSensor_data/BREE_WY22-23/WY22-WY23_WD5_soil_temp_VWC_2025-03-25.csv"),
  met_file         = file.path(repo_dir, "Data/Met_data/wade_2020-2024_met_2024-11-08.csv"),
  no3_file         = file.path(repo_dir, "Data/StreamSensor_data/wb_q_chem_20211001-20230930.csv"),
  doc_file         = file.path(repo_dir, "Data/StreamSensor_data/DOC.DOC@Wade_Brook.20221001.csv"),
  event_windows_df = wade_sampling_windows,
  emma_files       = emma_files_list,
  event_titles     = event_titles_list,
  q_lim            = c(0, 4.5),
  no3_lim          = c(0, 0.5),
  doc_lim          = c(0, 5),
  snow_lim         = c(0, 50),        
  air_temp_lim     = c(-15, 20),    
  precip_lim       = c(0, 2),
  soil_vwc_lim     = c(0.5, 0.6),     
  soil_temp_lim    = c(-2, 8),     
  base_font_size   = 18,
  #shading_df       = wade_shading_windows
)

print(wade_3x4_grid)

ggsave(
  filename = file.path(repo_dir, "Output/Hydrographs/Wade_3x4_EMMA_composite.jpg"), 
  plot = wade_3x4_grid, 
  width = 23, 
  height = 14, 
  dpi = 300
)
# Out:
# Warning message:
# “Removed 2496 rows containing missing values or values outside the scale range (`geom_segment()`).”
# Warning message:
# “`position_stack()` requires non-overlapping x intervals.”
# Warning message:
# “Removed 3 rows containing missing values or values outside the scale range (`geom_col()`).”
# `geom_smooth()` using formula = 'y ~ x'
# Warning message:
# “Removed 2263 rows containing non-finite outside the scale range (`stat_smooth()`).”
# `geom_smooth()` using formula = 'y ~ x'
# Warning message:
# “Removed 264 rows containing non-finite outside the scale range (`stat_smooth()`).”
# `geom_smooth()` using formula = 'y ~ x'
# `geom_smooth()` using formula = 'y ~ x'
# Warning message:
# “Removed 1728 rows containing missing values or values outside the scale range (`geom_segment()`).”
# `geom_smooth()` using formula = 'y ~ x'
# Warning message:
# “Removed 1066 rows containing non-finite outside the scale range (`stat_smooth()`).”
# `geom_smooth()` using formula = 'y ~ x'
# Warning message:
# “Removed 432 rows containing non-finite outside the scale range (`stat_smooth()`).”
# `geom_smooth()` using formula = 'y ~ x'
# `geom_smooth()` using formula = 'y ~ x'
# Warning message:
# “Removed 2951 rows containing missing values or values outside the scale range (`geom_segment()`).”
# Warning message:
# “Removed 1 row containing missing values or values outside the scale range (`geom_line()`).”
# Warning message:
# “Removed 12 rows containing missing values or values outside the scale range (`geom_col()`).”
# Warning message:
# “Removed 38 rows containing missing values or values outside the scale range (`geom_line()`).”
# `geom_smooth()` using formula = 'y ~ x'
# Warning message:
# “Removed 3191 rows containing non-finite outside the scale range (`stat_smooth()`).”
# `geom_smooth()` using formula = 'y ~ x'
# Warning message:
# “Removed 651 rows containing non-finite outside the scale range (`stat_smooth()`).”
# `geom_smooth()` using formula = 'y ~ x'
# `geom_smooth()` using formula = 'y ~ x'
# Warning message:
# “Removed 2496 rows containing missing values or values outside the scale range (`geom_segment()`).”
# Warning message:
# “`position_stack()` requires non-overlapping x intervals.”
# Warning message:
# “Removed 3 rows containing missing values or values outside the scale range (`geom_col()`).”
# `geom_smooth()` using formula = 'y ~ x'
# Warning message:
# “Removed 2263 rows containing non-finite outside the scale range (`stat_smooth()`).”
# `geom_smooth()` using formula = 'y ~ x'
# Warning message:
# “Removed 264 rows containing non-finite outside the scale range (`stat_smooth()`).”
# `geom_smooth()` using formula = 'y ~ x'
# `geom_smooth()` using formula = 'y ~ x'
# Warning message:
# “Removed 1728 rows containing missing values or values outside the scale range (`geom_segment()`).”
# `geom_smooth()` using formula = 'y ~ x'
# Warning message:
# “Removed 1066 rows containing non-finite outside the scale range (`stat_smooth()`).”
# `geom_smooth()` using formula = 'y ~ x'
# Warning message:
# “Removed 432 rows containing non-finite outside the scale range (`stat_smooth()`).”
# `geom_smooth()` using formula = 'y ~ x'
# `geom_smooth()` using formula = 'y ~ x'
# Warning message:
# “Removed 2951 rows containing missing values or values outside the scale range (`geom_segment()`).”
# Warning message:
# “Removed 1 row containing missing values or values outside the scale range (`geom_line()`).”
# Warning message:
# “Removed 12 rows containing missing values or values outside the scale range (`geom_col()`).”
# Warning message:
# “Removed 38 rows containing missing values or values outside the scale range (`geom_line()`).”
# `geom_smooth()` using formula = 'y ~ x'
# Warning message:
# “Removed 3191 rows containing non-finite outside the scale range (`stat_smooth()`).”
# `geom_smooth()` using formula = 'y ~ x'
# Warning message:
# “Removed 651 rows containing non-finite outside the scale range (`stat_smooth()`).”
# `geom_smooth()` using formula = 'y ~ x'
# `geom_smooth()` using formula = 'y ~ x'
# plot without title

# %%
library(fs)
library(ggplot2)

home_dir <- Sys.getenv("HOME")
repo_dir <- file.path(home_dir, "OneDrive/git-repos/LCBP-interannual-EMMAs")
source(file.path(repo_dir, "Functions/plot_multi_event_emma_grid.R"))
data_dir <- file.path(repo_dir, "Output/EMMA-results/")

hford_sampling_windows <- data.frame(
  start = as.POSIXct(c("2023-02-07 00:00", "2023-03-20 00:00", "2023-03-30 00:00"), tz = "UTC"),
  end   = as.POSIXct(c("2023-02-13 23:59", "2023-03-25 23:59", "2023-04-03 23:59"), tz = "UTC")
)

# Shade these in pale yellow across panels
hford_shading_windows <- data.frame(
  start = as.POSIXct(c("2023-02-09 05:15", "2023-03-21 06:00", "2023-03-31 06:00"), tz = "UTC"),
  end   = as.POSIXct(c("2023-02-19 04:00", "2023-03-23 23:30", "2023-04-11 17:15"), tz = "UTC")
)

hungerford_emma_feb_ros = file.path(data_dir, "Hungerford_Feb_ROS_fractions.csv")
hungerford_emma_mar_thm = file.path(data_dir, "Hungerford_Mar_therm_fractions.csv")
hungerford_emma_freshet = file.path(data_dir, "Hungerford_spring_melt_fractions.csv")

emma_files_list <- c(
  hungerford_emma_feb_ros,
  hungerford_emma_mar_thm,
  hungerford_emma_freshet
)

event_titles_list <- c("February ROS", "March thermal", "Final spring melt")

hungerford_3x4_grid <- plot_multi_event_grid(
  site_name        = "Hungerford",
  q_file           = file.path(repo_dir, "Data/StreamSensor_data/hb_q_chem_20211001-20230930.csv"),
  snow_file        = file.path(repo_dir, "Data/Met_data/enf-noaa-precip-WYW23.csv"),
  soil_file_6cm        = file.path(repo_dir, "Data/SoilSensor_data", "Swanton_Faulkner/Middle_Teros_brief.csv"),
  soil_file_15cm   = file.path(repo_dir, "Data/SoilSensor_data/BREE_WY22-23/WY22-WY23_HW1_soil_temp_VWC_2025-02-22.csv"),
  met_file         = file.path(repo_dir, "Data/Met_data/hungerford_2020-2024_met_2024-11-08.csv"),
  no3_file         = file.path(repo_dir, "Data/StreamSensor_data/hb_q_chem_20211001-20230930.csv"),
  doc_file         = file.path(repo_dir, "Data/StreamSensor_data/DOC.DOC@Hungerford_Brook.20221001.csv"),
  event_windows_df = hford_sampling_windows,
  emma_files       = emma_files_list,
  event_titles     = event_titles_list,
  q_lim            = c(0, 12),
  no3_lim          = c(0, 8),
  doc_lim          = c(0, 25),
  snow_lim         = c(0, 50),       
  air_temp_lim     = c(-15, 10),
  precip_lim       = c(0, 2),
  soil_vwc_lim     = c(0.3, 0.5),      
  soil_temp_lim    = c(-2, 5),      
  base_font_size   = 18,
  #shading_df       = hford_shading_windows
)

print(hungerford_3x4_grid)

ggsave(
  filename = file.path(repo_dir, "Output/Hydrographs/Hungerford_3x4_EMMA_composite.jpg"), 
  plot = hungerford_3x4_grid, 
  width = 23, 
  height = 14, 
  dpi = 300
)
# Out:
# Warning message:
# “`position_stack()` requires non-overlapping x intervals.”
# `geom_smooth()` using formula = 'y ~ x'
# `geom_smooth()` using formula = 'y ~ x'
# `geom_smooth()` using formula = 'y ~ x'
# `geom_smooth()` using formula = 'y ~ x'
# Warning message:
# “Removed 672 rows containing non-finite outside the scale range (`stat_smooth()`).”
# Warning message:
# “`position_stack()` requires non-overlapping x intervals.”
# Warning message:
# “Removed 191 rows containing missing values or values outside the scale range (`geom_line()`).”
# Warning message:
# “Removed 9 rows containing missing values or values outside the scale range (`geom_line()`).”
# `geom_smooth()` using formula = 'y ~ x'
# `geom_smooth()` using formula = 'y ~ x'
# `geom_smooth()` using formula = 'y ~ x'
# `geom_smooth()` using formula = 'y ~ x'
# Warning message:
# “Removed 6 rows containing missing values or values outside the scale range (`geom_col()`).”
# `geom_smooth()` using formula = 'y ~ x'
# `geom_smooth()` using formula = 'y ~ x'
# Warning message:
# “`position_stack()` requires non-overlapping x intervals.”
# `geom_smooth()` using formula = 'y ~ x'
# `geom_smooth()` using formula = 'y ~ x'
# `geom_smooth()` using formula = 'y ~ x'
# `geom_smooth()` using formula = 'y ~ x'
# Warning message:
# “Removed 672 rows containing non-finite outside the scale range (`stat_smooth()`).”
# Warning message:
# “`position_stack()` requires non-overlapping x intervals.”
# Warning message:
# “Removed 191 rows containing missing values or values outside the scale range (`geom_line()`).”
# Warning message:
# “Removed 9 rows containing missing values or values outside the scale range (`geom_line()`).”
# `geom_smooth()` using formula = 'y ~ x'
# `geom_smooth()` using formula = 'y ~ x'
# `geom_smooth()` using formula = 'y ~ x'
# `geom_smooth()` using formula = 'y ~ x'
# Warning message:
# “Removed 6 rows containing missing values or values outside the scale range (`geom_col()`).”
# `geom_smooth()` using formula = 'y ~ x'
# `geom_smooth()` using formula = 'y ~ x'
# plot without title

# %%
library(fs)
library(ggplot2)
library(patchwork)
library(tidyverse)
library(lubridate)
library(data.table)

home_dir <- Sys.getenv("HOME")
repo_dir <- file.path(home_dir, "OneDrive/git-repos/LCBP-interannual-EMMAs")
source(file.path(repo_dir, "Functions/plot_single_event_emma.R"))
data_dir <- file.path(repo_dir, "Output/EMMA-results/")

# Define the window strictly for the February ROS event
feb_ros_window <- c("2023-02-07 00:00", "2023-02-13 23:59")
feb_ros_shading <- data.frame(
  start = as.POSIXct("2023-02-09 05:15", tz = "UTC"),
  end   = as.POSIXct("2023-02-19 04:00", tz = "UTC")
)

hungerford_feb_ros_plot <- plot_single_event_emma(
  site_name        = "Hungerford",
  plot_range       = feb_ros_window,
  q_file           = file.path(repo_dir, "Data/StreamSensor_data/hb_q_chem_20211001-20230930.csv"),
  snow_file        = file.path(repo_dir, "Data/Met_data/enf-noaa-precip-WYW23.csv"),
  soil_file_6cm    = file.path(repo_dir, "Data/SoilSensor_data", "Swanton_Faulkner/Middle_Teros_brief.csv"),
  soil_file_15cm   = file.path(repo_dir, "Data/SoilSensor_data/BREE_WY22-23/WY22-WY23_HW1_soil_temp_VWC_2025-02-22.csv"),
  met_file         = file.path(repo_dir, "Data/Met_data/hungerford_2020-2024_met_2024-11-08.csv"),
  emma_frac_file   = file.path(data_dir, "Hungerford_Feb_ROS_fractions.csv"),
  no3_file         = file.path(repo_dir, "Data/StreamSensor_data/hb_q_chem_20211001-20230930.csv"),
  doc_file         = file.path(repo_dir, "Data/StreamSensor_data/DOC.DOC@Hungerford_Brook.20221001.csv"),
  q_lim            = c(0, 12),
  no3_lim          = c(0, 8),
  doc_lim          = c(0, 25),
  snow_lim         = c(0, 50),        
  air_temp_lim     = c(-15, 10),
  precip_lim       = c(0, 2),
  soil_vwc_lim     = c(0.3, 0.5),      
  soil_temp_lim    = c(-2, 5),      
  base_font_size   = 14,
  event_title      = "Hungerford - February Rain-on-Snow Event",
  shading_df       = feb_ros_shading
)

print(hungerford_feb_ros_plot)

ggsave(
  filename = file.path(repo_dir, "Output/Hydrographs/Hungerford_Feb_ROS_composite.jpg"), 
  plot = hungerford_feb_ros_plot, 
  width = 14,  # Adjusted width for a single tall panel layout with side legends
  height = 12, 
  dpi = 300
)
# Out:
# Warning message:
# “Removed 1 row containing missing values or values outside the scale range (`geom_rect()`).”
# Warning message:
# “`position_stack()` requires non-overlapping x intervals.”
# Warning message:
# “Removed 1 row containing missing values or values outside the scale range (`geom_rect()`).”
# Warning message:
# “Removed 1 row containing missing values or values outside the scale range (`geom_rect()`).”
# `geom_smooth()` using formula = 'y ~ x'
# `geom_smooth()` using formula = 'y ~ x'
# `geom_smooth()` using formula = 'y ~ x'
# `geom_smooth()` using formula = 'y ~ x'
# Warning message:
# “Removed 672 rows containing non-finite outside the scale range (`stat_smooth()`).”
# Warning message:
# “Removed 1 row containing missing values or values outside the scale range (`geom_rect()`).”
# Warning message:
# “Removed 1 row containing missing values or values outside the scale range (`geom_rect()`).”
# Warning message:
# “`position_stack()` requires non-overlapping x intervals.”
# Warning message:
# “Removed 1 row containing missing values or values outside the scale range (`geom_rect()`).”
# Warning message:
# “Removed 1 row containing missing values or values outside the scale range (`geom_rect()`).”
# `geom_smooth()` using formula = 'y ~ x'
# `geom_smooth()` using formula = 'y ~ x'
# `geom_smooth()` using formula = 'y ~ x'
# `geom_smooth()` using formula = 'y ~ x'
# Warning message:
# “Removed 672 rows containing non-finite outside the scale range (`stat_smooth()`).”
# Warning message:
# “Removed 1 row containing missing values or values outside the scale range (`geom_rect()`).”
# plot without title

# %%
library(fs)
library(ggplot2)
library(patchwork)
library(tidyverse)
library(lubridate)
library(data.table)

home_dir <- Sys.getenv("HOME")
repo_dir <- file.path(home_dir, "OneDrive/git-repos/LCBP-interannual-EMMAs")
source(file.path(repo_dir, "Functions/plot_single_event_emma.R"))
data_dir <- file.path(repo_dir, "Output/EMMA-results/")

# Define the window strictly for the February ROS event
feb_ros_window <- c("2023-02-07 00:00", "2023-02-13 23:59")
feb_ros_shading <- data.frame(
  start = as.POSIXct("2023-02-09 05:15", tz = "UTC"),
  end   = as.POSIXct("2023-02-19 04:00", tz = "UTC")
)

hungerford_feb_ros_plot <- plot_single_event_emma(
  site_name        = "Hungerford",
  plot_range       = feb_ros_window,
  q_file           = file.path(repo_dir, "Data/StreamSensor_data/hb_q_chem_20211001-20230930.csv"),
  snow_file        = file.path(repo_dir, "Data/Met_data/enf-noaa-precip-WYW23.csv"),
  soil_file_6cm    = file.path(repo_dir, "Data/SoilSensor_data", "Swanton_Faulkner/Middle_Teros_brief.csv"),
  soil_file_15cm   = file.path(repo_dir, "Data/SoilSensor_data/BREE_WY22-23/WY22-WY23_HW1_soil_temp_VWC_2025-02-22.csv"),
  met_file         = file.path(repo_dir, "Data/Met_data/hungerford_2020-2024_met_2024-11-08.csv"),
  emma_frac_file   = file.path(data_dir, "Hungerford_Feb_ROS_fractions.csv"),
  no3_file         = file.path(repo_dir, "Data/StreamSensor_data/hb_q_chem_20211001-20230930.csv"),
  doc_file         = file.path(repo_dir, "Data/StreamSensor_data/DOC.DOC@Hungerford_Brook.20221001.csv"),
  q_lim            = c(0, 12),
  no3_lim          = c(0, 8),
  doc_lim          = c(0, 25),
  snow_lim         = c(0, 50),        
  air_temp_lim     = c(-15, 10),
  precip_lim       = c(0, 2),
  soil_vwc_lim     = c(0.3, 0.5),      
  soil_temp_lim    = c(-2, 5),      
  base_font_size   = 14,
  event_title      = "Hungerford - February Rain-on-Snow Event",
  shading_df       = feb_ros_shading
)

print(hungerford_feb_ros_plot)

ggsave(
  filename = file.path(repo_dir, "Output/Hydrographs/Hungerford_Feb_ROS_composite.jpg"), 
  plot = hungerford_feb_ros_plot, 
  width = 14,  # Adjusted width for a single tall panel layout with side legends
  height = 12, 
  dpi = 300
)

# %%
library(fs)
library(ggplot2)
library(patchwork)
library(tidyverse)
library(lubridate)
library(data.table)

home_dir <- Sys.getenv("HOME")
repo_dir <- file.path(home_dir, "OneDrive/git-repos/LCBP-interannual-EMMAs")
source(file.path(repo_dir, "Functions/plot_single_event_emma.R"))
data_dir <- file.path(repo_dir, "Output/EMMA-results/")

# Define the window strictly for the Wade February ROS event
wade_feb_ros_window <- c("2023-02-08 00:00", "2023-02-20 23:59")
wade_feb_ros_shading <- data.frame(
  start = as.POSIXct("2023-02-09 05:15", tz = "UTC"),
  end   = as.POSIXct("2023-02-19 04:00", tz = "UTC")
)

wade_feb_ros_plot <- plot_single_event_emma(
  site_name        = "Wade",
  plot_range       = wade_feb_ros_window,
  q_file           = file.path(repo_dir, "Data/StreamSensor_data/wb_q_chem_20211001-20230930.csv"),
  snow_file        = file.path(repo_dir, "Data/Met_data/Wade_cocorahs-vt-fr-30-20221115-20250414-2.csv"),
  soil_file_6cm    = file.path(repo_dir, "Data/SoilSensor_data/Ranch_Brook/RanchBrook_TMS4_WY23_SML1_data.csv"),
  soil_file_15cm   = file.path(repo_dir, "Data/SoilSensor_data/BREE_WY22-23/WY22-WY23_WD5_soil_temp_VWC_2025-03-25.csv"),
  met_file         = file.path(repo_dir, "Data/Met_data/wade_2020-2024_met_2024-11-08.csv"),
  emma_frac_file   = file.path(data_dir, "Wade_Feb_ROS_fractions.csv"),
  no3_file         = file.path(repo_dir, "Data/StreamSensor_data/wb_q_chem_20211001-20230930.csv"),
  doc_file         = file.path(repo_dir, "Data/StreamSensor_data/DOC.DOC@Wade_Brook.20221001.csv"),
  q_lim            = c(0, 4.5),
  no3_lim          = c(0, 0.5),
  doc_lim          = c(0, 5),
  snow_lim         = c(0, 50),        
  air_temp_lim     = c(-15, 20),
  precip_lim       = c(0, 2),
  soil_vwc_lim     = c(0.5, 0.6),      
  soil_temp_lim    = c(-2, 8),      
  base_font_size   = 18,
  event_title      = "Wade - February Rain-on-Snow Event",
  shading_df       = wade_feb_ros_shading
)

print(wade_feb_ros_plot)

ggsave(
  filename = file.path(repo_dir, "Output/Hydrographs/Wade_Feb_ROS_composite.jpg"), 
  plot = wade_feb_ros_plot, 
  width = 14,  
  height = 12, 
  dpi = 300
)
# Out:
# Warning message:
# “Removed 2496 rows containing missing values or values outside the scale range (`geom_segment()`).”
# Warning message:
# “`position_stack()` requires non-overlapping x intervals.”
# Warning message:
# “Removed 3 rows containing missing values or values outside the scale range (`geom_col()`).”
# `geom_smooth()` using formula = 'y ~ x'
# Warning message:
# “Removed 2263 rows containing non-finite outside the scale range (`stat_smooth()`).”
# `geom_smooth()` using formula = 'y ~ x'
# Warning message:
# “Removed 264 rows containing non-finite outside the scale range (`stat_smooth()`).”
# `geom_smooth()` using formula = 'y ~ x'
# `geom_smooth()` using formula = 'y ~ x'
# Warning message:
# “Removed 2496 rows containing missing values or values outside the scale range (`geom_segment()`).”
# Warning message:
# “`position_stack()` requires non-overlapping x intervals.”
# Warning message:
# “Removed 3 rows containing missing values or values outside the scale range (`geom_col()`).”
# `geom_smooth()` using formula = 'y ~ x'
# Warning message:
# “Removed 2263 rows containing non-finite outside the scale range (`stat_smooth()`).”
# `geom_smooth()` using formula = 'y ~ x'
# Warning message:
# “Removed 264 rows containing non-finite outside the scale range (`stat_smooth()`).”
# `geom_smooth()` using formula = 'y ~ x'
# `geom_smooth()` using formula = 'y ~ x'
# plot without title

# %%
library(fs)
library(ggplot2)
library(patchwork)
library(tidyverse)
library(lubridate)
library(data.table)

home_dir <- Sys.getenv("HOME")
repo_dir <- file.path(home_dir, "OneDrive/git-repos/LCBP-interannual-EMMAs")
source(file.path(repo_dir, "Functions/plot_single_event_emma.R"))
data_dir <- file.path(repo_dir, "Output/EMMA-results/")

# Define the window strictly for the February ROS event
mar_therm_window <- c("2023-03-16 00:00", "2023-03-27 23:59")
mar_therm_shading <- data.frame(
  start = as.POSIXct("2023-03-21 05:15", tz = "UTC"),
  end   = as.POSIXct("2023-03-26 04:00", tz = "UTC")
)

hungerford_feb_ros_plot <- plot_single_event_emma(
  site_name        = "Hungerford",
  plot_range       = mar_therm_window,
  q_file           = file.path(repo_dir, "Data/StreamSensor_data/hb_q_chem_20211001-20230930.csv"),
  snow_file        = file.path(repo_dir, "Data/Met_data/enf-noaa-precip-WYW23.csv"),
  soil_file_6cm    = file.path(repo_dir, "Data/SoilSensor_data", "Swanton_Faulkner/Middle_Teros_brief.csv"),
  soil_file_15cm   = file.path(repo_dir, "Data/SoilSensor_data/BREE_WY22-23/WY22-WY23_HW1_soil_temp_VWC_2025-02-22.csv"),
  met_file         = file.path(repo_dir, "Data/Met_data/hungerford_2020-2024_met_2024-11-08.csv"),
  emma_frac_file   = file.path(data_dir, "Hungerford_Mar_therm_fractions.csv"),
  no3_file         = file.path(repo_dir, "Data/StreamSensor_data/hb_q_chem_20211001-20230930.csv"),
  doc_file         = file.path(repo_dir, "Data/StreamSensor_data/DOC.DOC@Hungerford_Brook.20221001.csv"),
  q_lim            = c(0, 12),
  no3_lim          = c(0, 8),
  doc_lim          = c(0, 25),
  snow_lim         = c(0, 50),        
  air_temp_lim     = c(-15, 10),
  precip_lim       = c(0, 2),
  soil_vwc_lim     = c(0.3, 0.5),      
  soil_temp_lim    = c(-2, 5),      
  base_font_size   = 14,
  event_title      = "Hungerford - February Rain-on-Snow Event",
  shading_df       = feb_ros_shading
)

print(hungerford_feb_ros_plot)

ggsave(
  filename = file.path(repo_dir, "Output/Hydrographs/Hungerford_Mar_therm_composite.jpg"), 
  plot = hungerford_feb_ros_plot, 
  width = 14,  # Adjusted width for a single tall panel layout with side legends
  height = 12, 
  dpi = 300
)
# Out:
# Warning message:
# “Removed 1 row containing missing values or values outside the scale range (`geom_rect()`).”
# Warning message:
# “`position_stack()` requires non-overlapping x intervals.”
# Warning message:
# “Removed 1 row containing missing values or values outside the scale range (`geom_rect()`).”
# Warning message:
# “Removed 1 row containing missing values or values outside the scale range (`geom_rect()`).”
# Warning message:
# “Removed 383 rows containing missing values or values outside the scale range (`geom_line()`).”
# Warning message:
# “Removed 99 rows containing missing values or values outside the scale range (`geom_line()`).”
# `geom_smooth()` using formula = 'y ~ x'
# `geom_smooth()` using formula = 'y ~ x'
# `geom_smooth()` using formula = 'y ~ x'
# Warning message:
# “Removed 14 rows containing non-finite outside the scale range (`stat_smooth()`).”
# `geom_smooth()` using formula = 'y ~ x'
# Warning message:
# “Removed 1 row containing missing values or values outside the scale range (`geom_rect()`).”
# Warning message:
# “Removed 1 row containing missing values or values outside the scale range (`geom_rect()`).”
# Warning message:
# “`position_stack()` requires non-overlapping x intervals.”
# Warning message:
# “Removed 1 row containing missing values or values outside the scale range (`geom_rect()`).”
# Warning message:
# “Removed 1 row containing missing values or values outside the scale range (`geom_rect()`).”
# Warning message:
# “Removed 383 rows containing missing values or values outside the scale range (`geom_line()`).”
# Warning message:
# “Removed 99 rows containing missing values or values outside the scale range (`geom_line()`).”
# `geom_smooth()` using formula = 'y ~ x'
# `geom_smooth()` using formula = 'y ~ x'
# `geom_smooth()` using formula = 'y ~ x'
# Warning message:
# “Removed 14 rows containing non-finite outside the scale range (`stat_smooth()`).”
# `geom_smooth()` using formula = 'y ~ x'
# Warning message:
# “Removed 1 row containing missing values or values outside the scale range (`geom_rect()`).”
# plot without title
