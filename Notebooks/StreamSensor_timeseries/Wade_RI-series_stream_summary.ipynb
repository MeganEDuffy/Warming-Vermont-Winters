# %%
# Steram summary plotting function lives here
source("/home/millieginty/OneDrive/git-repos/LCBP-interannual-EMMAs/Functions/plot_stream_summary.R")

# 1. Overall time range
my_range <- as.POSIXct(c("2021-01-01", "2025-04-20"), tz = "UTC")

# 2. Storm event time range definintions
my_events <- list(
  start = c('2023-02-14', '2023-03-21', '2023-03-30'),
  end   = c('2023-02-20', '2023-03-26', '2023-04-15')
)

# 3. Call the steam summary plotting function
wade_plot <- plot_stream_summary(
  site_name      = "Wade",
  plot_range     = my_range,
  event_bounds   = my_events,
  q_file         = "/home//millieginty//OneDrive/git-repos/LCBP-interannual-EMMAs/Data/StreamSensor_data/wb_q_chem_20211001-20230930.csv",
  exo_file       = "/home//millieginty//OneDrive/git-repos/cQ_analysis/cond-hydrograph-separation/newrnet/data/wade_2023_sC_2024-07-31.csv",
  grab_chem_file = "/home//millieginty//OneDrive/git-repos/EMMA/isco_metadata/LCBP_RI_sample_index/RI23-IC-ICP-isotope-toc-joined-Wade.csv",
  doc_file       = "/home//millieginty//OneDrive/git-repos/EMMA/data/newrnet-q-scan/DOC.DOC@Wade_Brook.20221001.csv",
  ic_sc_file     = "/home//millieginty//OneDrive/git-repos/LCBP-interannual-EMMAs/Data/GrabSample_data/RI23-ion-chromatography/RI23_IC_uS-totals.csv",
  q_lim = c(0, 4),    # Default for Wade
  sc_lim = c(0, 60), # Default for Wade
  chem_lim = c(0, 5)  # Default for Wade
)

print(wade_plot)
# Out:
# [1] "Rows in Q: 69949"
# [1] "Rows in EXO: 34696"
# [1] "Rows in Joined Data: 34696"
#              timestamp    q_cms       NO3          TP NO3_source TP_source
#                 <POSc>    <num>     <num>       <num>     <char>    <char>
# 1: 2023-01-01 00:02:00 2.914767 0.3141051 0.000900000     sensor    sensor
# 2: 2023-01-01 00:17:00 2.922619 0.3085314 0.010773904     sensor    sensor
# 3: 2023-01-01 00:32:00 2.902996 0.3200421 0.003348343     sensor    sensor
# 4: 2023-01-01 00:47:00 2.906919 0.3176524 0.002723394     sensor    sensor
# 5: 2023-01-01 01:02:00 2.914767 0.3083622 0.008888137     sensor    sensor
# 6: 2023-01-01 01:17:00 2.902996 0.3118549 0.006985454     sensor    sensor
#        X           Timestamp    sC
#    <int>              <char> <num>
# 1:     1 2023-01-01 00:02:00 18.59
# 2:     2 2023-01-01 00:17:00 18.54
# 3:     3 2023-01-01 00:32:00 18.48
# 4:     4 2023-01-01 00:47:00 18.44
# 5:     5 2023-01-01 01:02:00 18.44
# 6:     6 2023-01-01 01:17:00 18.47
# ...
