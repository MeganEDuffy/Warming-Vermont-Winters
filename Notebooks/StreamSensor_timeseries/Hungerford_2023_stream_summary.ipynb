# %%
# Steram summary plotting function lives here
source("~/OneDrive/git-repos/LCBP-interannual-EMMAs/Functions/plot_stream_summary.R")

# 1. Overall time range
hungerford_range <- as.POSIXct(c("2023-01-01", "2023-04-20"), tz = "UTC")

# 2. Storm event time range definintions
hungerford_events <- list(
  start = c('2023-02-14', '2023-03-21', '2023-03-30'),
  end   = c('2023-02-20', '2023-03-26', '2023-04-15')
)

# 3. Call the steam summary plotting function
hungerford_plot <- plot_stream_summary(
  site_name      = "Hungerford",
  plot_range     = hungerford_range,
  event_bounds   = hungerford_events,
  q_file         = "~/OneDrive/git-repos/LCBP-interannual-EMMAs/Data/StreamSensor_data/hb_q_chem_20211001-20230930.csv",
  exo_file       = "~/OneDrive/git-repos/cQ_analysis/cond-hydrograph-separation/newrnet/data/hungerford_2023_sC_2024-07-31.csv",
  grab_chem_file = "~/OneDrive/git-repos/EMMA/isco_metadata/LCBP_RI_sample_index/RI23-IC-ICP-isotope-toc-joined.csv",
  doc_file       = "~/OneDrive/git-repos/EMMA/data/newrnet-q-scan/DOC.DOC@Hungerford_Brook.20221001.csv",
  ic_sc_file     = "~/OneDrive/git-repos/LCBP-interannual-EMMAs/Data/GrabSample_data/RI23-ion-chromatography/RI23_IC_uS-totals.csv",
  q_lim        = c(0, 12),
  sc_lim       = c(0, 550),
  chem_lim     = c(0, 50)
)

print(hungerford_plot)
# Out:
# Warning message:
# “package ‘tidyverse’ was built under R version 4.2.3”
# Warning message:
# “package ‘ggplot2’ was built under R version 4.2.3”
# Warning message:
# “package ‘tibble’ was built under R version 4.2.3”
# Warning message:
# “package ‘tidyr’ was built under R version 4.2.3”
# Warning message:
# “package ‘readr’ was built under R version 4.2.3”
# Warning message:
# “package ‘purrr’ was built under R version 4.2.3”
# Warning message:
# “package ‘dplyr’ was built under R version 4.2.3”
# Warning message:
# “package ‘stringr’ was built under R version 4.2.3”
# Warning message:
# “package ‘forcats’ was built under R version 4.2.3”
# Warning message:
# “package ‘lubridate’ was built under R version 4.2.3”
# ── Attaching core tidyverse packages ────────────────────────────────────────────────────────────────────────────────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ...

# %%
# Stream summary plotting function with sample datetime overlaying Q, sC
source("~/OneDrive/git-repos/LCBP-interannual-EMMAs/Functions/plot_samples_Q.R")

# 1. Winter time range
hungerford_range <- as.POSIXct(c("2022-12-31", "2023-04-20"), tz = "UTC")

# 2. Output path 
plots_dir <- "~/OneDrive/git-repos/LCBP-interannual-EMMAs/Output/Hydrographs/"

# 3. Call the timeline function
hungerford_timeline <- plot_samples_q(
  site_name      = "Hungerford",
  plot_range     = hungerford_range,
  event_bounds   = hungerford_events,
  q_file         = "~/OneDrive/git-repos/LCBP-interannual-EMMAs/Data/StreamSensor_data/hb_q_chem_20211001-20230930.csv",
  exo_file       = "~/OneDrive/git-repos/cQ_analysis/cond-hydrograph-separation/newrnet/data/hungerford_2023_sC_2024-07-31.csv",
  grab_chem_file = "~/OneDrive/git-repos/EMMA/isco_metadata/LCBP_RI_sample_index/RI23-IC-ICP-isotope-toc-joined.csv",
  q_lim          = c(0, 12),
  sc_lim         = c(0, 550),
  output_dir     = plots_dir
)

print(hungerford_timeline)
# Out:
# Warning message:
# “There was 1 warning in `mutate()`.
# ℹ In argument: `timestamp = mdy_hm(paste(Date, Time), tz = "UTC")`.
# Caused by warning:
# !  3 failed to parse.”
# Successfully saved timeline plot to: ~/OneDrive/git-repos/LCBP-interannual-EMMAs/Output/Hydrographs//Hungerford_sample_timeline_20221231.jpg
# plot without title
