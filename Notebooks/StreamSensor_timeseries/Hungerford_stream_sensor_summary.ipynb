# %%
# Steram sensor summary plotting function lives here
source("/home/millieginty/OneDrive/git-repos/LCBP-interannual-EMMAs/Functions/stream_sensor_summary.R")

# Define plotting range
timeseries_range <- as.POSIXct(c("2022-10-01", "2025-05-01"), tz = "UTC")

# Paths to corrected AQUARIUS csvs
hungerford_sensors <- stream_sensor_summary(
  site_name = "Hungerford",
  plot_range = timeseries_range,
  q_file    = "/home/millieginty/OneDrive/git-repos/LCBP-interannual-EMMAs/Data/StreamSensor_data/Discharge.Discharge.NEWRnet@Hungerford_Brook.20221001.csv",
  no3_file  = "/home/millieginty/OneDrive/git-repos/LCBP-interannual-EMMAs/Data/StreamSensor_data/Placeholder_Nitrate_N.NO3N@Hungerford_Brook.20221001.csv", #Just through 2023, a placeholder until I can download NO3 from Aq
  doc_file  = "/home/millieginty/OneDrive/git-repos/LCBP-interannual-EMMAs/Data/StreamSensor_data/DOC.DOC@Hungerford_Brook.20221001.csv",
  turb_file = "/home/millieginty/OneDrive/git-repos/LCBP-interannual-EMMAs/Data/StreamSensor_data/Turbidity,_Form_Neph.Turbidity@Hungerford_Brook.20221001.csv",
  q_lim     = c(0, 15),
  no3_lim   = c(0, 12), # can't see December 18, 2023 ROS event (goes to ~1.5 mg/L N-NO3)
  doc_lim   = c(0, 35),
  turb_lim  = c(0, 1000)
)

print(hungerford_sensors)
ggsave("/home/millieginty/OneDrive/git-repos/LCBP-interannual-EMMAs/Output/Hungerford_2022-2025_stream_sensor_timeseries.jpg")
# Out:
# Warning message:
# “Removed 1 row containing missing values or values outside the scale range
# (`geom_rect()`).”
# Warning message:
# “Removed 4086 rows containing missing values or values outside the scale range
# (`geom_line()`).”
# Warning message:
# “Removed 1 row containing missing values or values outside the scale range
# (`geom_rect()`).”
# Warning message:
# “Removed 34952 rows containing missing values or values outside the scale range
# (`geom_line()`).”
# Warning message:
# “Removed 1 row containing missing values or values outside the scale range
# (`geom_rect()`).”
# Warning message:
# “Removed 1 row containing missing values or values outside the scale range
# (`geom_rect()`).”
# Warning message:
# “Removed 14608 rows containing missing values or values outside the scale range
# (`geom_line()`).”
# Saving 7 x 7 in image
# Warning message:
# “Removed 1 row containing missing values or values outside the scale range
# (`geom_rect()`).”
# Warning message:
# ...
