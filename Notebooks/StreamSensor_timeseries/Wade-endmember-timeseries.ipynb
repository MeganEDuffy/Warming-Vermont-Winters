# %%
source("/home//millieginty/OneDrive/git-repos/LCBP-interannual-EMMAs/Functions/interannual_groundwater_timeseries.R")

RI_data_dir <- "/home//millieginty/OneDrive/git-repos/LCBP-interannual-EMMAs/Data/GrabSample_data/"
Wade_tracers <- c("dD", "d18O", "Ca_mg_L", "Mg_mg_L", "Si_mg_L", "Mn_mg_L", "Na_mg_L")

wade_interannual_plot <- plot_interannual_groundwater(RI_data_dir, "Wade", Wade_tracers)
print(wade_interannual_plot)
# Out:
# Warning message:
# “Removed 18 rows containing missing values or values outside the scale range
# (`geom_line()`).”
# Warning message:
# “Removed 19 rows containing missing values or values outside the scale range
# (`geom_point()`).”
# Warning message:
# “Removed 18 rows containing missing values or values outside the scale range
# (`geom_line()`).”
# Warning message:
# “Removed 19 rows containing missing values or values outside the scale range
# (`geom_point()`).”
# Warning message:
# “Removed 1 row containing missing values or values outside the scale range
# (`geom_point()`).”
# Warning message:
# “Removed 1 row containing missing values or values outside the scale range
# (`geom_point()`).”
# Warning message:
# “Removed 1 row containing missing values or values outside the scale range
# (`geom_point()`).”
# Warning message:
# “Removed 1 row containing missing values or values outside the scale range
# (`geom_point()`).”
# Warning message:
# “Removed 1 row containing missing values or values outside the scale range
# (`geom_point()`).”
# plot without title

# %%
# Call the bivariate function for dD vs Calcium
wade_bivariate <- groundwater_bivariate(
  data_dir = "/home//millieginty/OneDrive/git-repos/LCBP-interannual-EMMAs/Data/GrabSample_data/",
  site_name = "Wade",
  tracer_x = "d18O", 
  tracer_y = "Ca_mg_L"
)

print(wade_bivariate)
# Out:
# Warning message:
# “Removed 20 rows containing missing values or values outside the scale range
# (`geom_point()`).”
# plot without title
