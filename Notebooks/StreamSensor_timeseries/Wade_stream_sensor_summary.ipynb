# %%
# Steram sensor summary plotting function lives here
source("/home/millieginty/OneDrive/git-repos/LCBP-interannual-EMMAs/Functions/stream_sensor_summary.R")

# Define plotting range
timeseries_range <- as.POSIXct(c("2022-10-01", "2025-05-01"), tz = "UTC")

# Paths to corrected AQUARIUS csvs
wade_sensors <- stream_sensor_summary(
  site_name = "Wade",
  plot_range = timeseries_range,
  q_file    = "/home/millieginty/OneDrive/git-repos/LCBP-interannual-EMMAs/Data/StreamSensor_data/Discharge.Discharge_cms@Wade_Brook.20221001.csv",
  no3_file  = "/home/millieginty/OneDrive/git-repos/LCBP-interannual-EMMAs/Data/StreamSensor_data/Nitrate_N.NO3N@Wade_Brook.20221001.csv",
  doc_file  = "/home/millieginty/OneDrive/git-repos/LCBP-interannual-EMMAs/Data/StreamSensor_data/DOC.DOC@Wade_Brook.20221001.csv",
  turb_file = "/home/millieginty/OneDrive/git-repos/LCBP-interannual-EMMAs/Data/StreamSensor_data/Turbidity,_Form_Neph.Turbidity@Wade_Brook.20221001.csv",
  q_lim     = c(0, 100),
  no3_lim   = c(0, 0.5), # can't see December 18, 2023 ROS event (goes to ~1.5 mg/L N-NO3)
  doc_lim   = c(0, 15),
  turb_lim  = c(0, 100)
)

print(wade_sensors)
ggsave("/home/millieginty/OneDrive/git-repos/LCBP-interannual-EMMAs/Output/Wade_2022-2025_stream_sensor_timeseries.jpg")
# Out:
# Warning message:
# “Removed 1 row containing missing values or values outside the scale range
# (`geom_rect()`).”
# Warning message:
# “Removed 14267 rows containing missing values or values outside the scale range
# (`geom_line()`).”
# Warning message:
# “Removed 1 row containing missing values or values outside the scale range
# (`geom_rect()`).”
# Warning message:
# “Removed 14479 rows containing missing values or values outside the scale range
# (`geom_line()`).”
# Warning message:
# “Removed 1 row containing missing values or values outside the scale range
# (`geom_rect()`).”
# Warning message:
# “Removed 1 row containing missing values or values outside the scale range
# (`geom_rect()`).”
# Warning message:
# “Removed 14608 rows containing missing values or values outside the scale range
# (`geom_line()`).”
# Saving 7 x 7 in image
# Warning message:
# “Removed 1 row containing missing values or values outside the scale range
# (`geom_rect()`).”
# Warning message:
# ...
